# %%
# %load_ext autoreload
# %autoreload 2

# %%
#  Run your entire pipeline
# !python main.py
# Out:
# ...
#     Deep Compression Pipeline v1.0
# ...
# [*] Computation Device: cpu
#
# [*] Loading MNIST Dataset...
# [*] Initializing Baseline MNIST_MLP Model...
#
# [*] Starting Baseline Training (5 Epochs)...
# Starting Training for 5 Epochs
# Epoch [1/5] | Loss: 0.3991 | Accuracy: 88.05%
# Epoch [2/5] | Loss: 0.1764 | Accuracy: 94.68%
# Epoch [3/5] | Loss: 0.1267 | Accuracy: 96.13%
# Epoch [4/5] | Loss: 0.0991 | Accuracy: 96.91%
# Epoch [5/5] | Loss: 0.0804 | Accuracy: 97.56%
#
# [*] Evaluating Baseline Model...
# ==> Test Accuracy: 96.91%
# [*] BASELINE ACCURACY: 96.91%
#
# ...
#         PHASE 2: PRUNING
# ...
# --- BEFORE PRUNING ---
# Total Weights:  234,752
# Active Weights: 234,752
# Zeroed Weights: 0
# Sparsity:       0.00%
#
# [*] Applying Magnitude Pruning (Target Sparsity: 50.0%)
# --- AFTER PRUNING ---
# Total Weights:  234,752
# Active Weights: 117,376
# Zeroed Weights: 117,376
# Sparsity:       50.00%
#
# [*] Global Sparsity achieved: 50.00%
#
# ...
