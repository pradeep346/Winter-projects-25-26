# %% [markdown]
# # <font size="7"> **Assignment-6**</font>
# I hope this assignment will give you clarity on how mathematical models like **Multilayer Perceptrons (MLP)** can be made from scratch using **PyTorch** & can be used to solve complex, non-linear geometric problems **without relying on black-box libraries**.
#
# ---
# # ⚫ **Mission Critical: The Exclusion Zone Protocol**
#
# **Date:** Year 2142
# **Location:** Exoplanet *Kepler-186f*   **Clearance:** IITians
#
# ---
#
# ### **⚫ The Story**
# Humanity has colonized the distant exoplanet *Kepler-186f*. While the surface is habitable, the planet's magnetic core is unstable. The **Global Defense Council (GDC)** has identified a dangerous phenomenon known as the **"Radiation Ring."**
#
# Sensors indicate that the safe zones on the planet follow a peculiar geometry:
# * ⚫ **The Core Zone:** Distance $< 2$ km from the colony center (Safe).
# * ⚫ **The Outer Wilds:** Distance $> 4$ km from the colony center (Safe).
# * ⚫ **The Dead Zone:** The region **between 2 km and 4 km** is flooded with lethal gamma radiation.
#
# Your engineering team has deployed **3,000 sensor drones** across the colony to map this danger. Each drone reports its coordinates $(x, y)$ and a binary label:
# * `1`: Radiation Detected (Dead Zone)
# * `0`: Safe Zone
#
#  **⚫ The Problem:** The sensors are cheap and prone to interference. Approximately **5%** of the drones are malfunctioning and reporting the wrong safety status (noise). The GDC mainframe is a legacy system that forbids the use of modern "Neural Libraries" (i.e., you cannot use `torch.nn` or `torch.optim`). You must build a **Multi-Layer Perceptron (MLP) from scratch** to filter out the noise and mathematically define the Exclusion Zone boundaries using **PyTorch**. ( Hint: You know this is a binary classification problem, which Loss function would you use?? )
#
# ---
#
# ### **⚫ Your Objective**
#
# 1.  **Initialize the System:** Use your **Group Number** as the random seed. This ensures your team works on a unique sensor distribution pattern.
# 2.  **Architect the Filter:** Construct a neural network with **3 hidden layers** (16 neurons each) to learn the non-linear "donut" shape of the Dead Zone.
# 3.  **Manual Calibration:** You cannot use auto-optimizers. You must manually calculate the gradients (Backpropagation) and update the system weights using **Gradient Descent**.
# 4.  **Verify Integrity:** Split your sensor data (70% training, 30% validation). Prove that your system doesn't just memorize the malfunctioning sensors (overfitting) but actually learns the geometric shape of the Dead Zone.
#
# ---
#
# ## ⚫ Engineering Constraints (Read Carefully)
#
# **1. Restricted Modules**
# *  **Forbidden:** You are strictly forbidden from importing `torch.nn` (Layers/Loss) or `torch.optim` (Optimizers).
# *  **Allowed:** `import torch`, `import matplotlib.pyplot`, `import pandas`, `import numpy`, using `sklearn`.
#
#
# **2. The Mechanics**
# * **Forward Pass:** Must be implemented using raw matrix multiplication (`torch.matmul`) and bias addition.
# * **Backward Pass:** You **MAY** use `loss.backward()` to compute gradients automatically (Autograd).
# * **Optimization:** You **MUST** implement the weight updates manually (Stochastic Gradient Descent).
#     > `w_new = w_old - learning_rate * w_old.grad`
#
# **3. Loss Function**
# Since `torch.nn` is banned, you must implement **Binary Cross Entropy** manually using basic tensor math.
#
# $$Loss = -\frac{1}{N} \sum_{i=1}^{N} [y_i \cdot \log(\hat{y}_i) + (1-y_i) \cdot \log(1-\hat{y}_i)]$$
#
# * **Note:** Ensure you handle the log of zero (numerical stability) or use `torch.clamp` to avoid `NaN` errors.
#
# **4. Visual Proof:** Your final output must include a Decision Boundary Map showing the "Donut" shape.
#
#
# ---
#
# ### ⚫ **The GDC Dashboard (Required Output)**
#
#
#
# The Global Defense Council requires visual confirmation that your system is stable before we can upload it to the drone fleet. You must generate a **3-Panel Heads-Up Display (HUD)** containing the following telemetry:
#
# **1. System Error Trajectory (Loss Plot)**
# * **Mission:** Plot the **Training Loss** (Blue) vs. **Validation Loss** (Orange) over all epochs.
# * **Why:** We need to confirm that the system is actually learning and not just diverging (exploding gradients).
#
# **2. Integrity Check (Accuracy Plot)**
# * **Mission:** Plot the **Training Accuracy** vs. **Validation Accuracy**.
# * **Why:** If Training Accuracy is high (95%) but Validation Accuracy is low (80%), you have failed to generalize. This is a sign of **Overfitting**—memorizing sensor noise instead of the Radiation Ring.
#
# **3. Geospatial Threat Map (Decision Boundary)**
# * **Mission:** Visualize the **Validation Set** on a 2D map.
# * **Overlay:** Draw the neural network's **Decision Boundary** (the contours where confidence = 0.5).
# * **Why:** The Commander needs to *see* the "Donut" shape. If your boundary looks like a jagged mess, the model is rejected.
#
# ---

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
GROUP_NUMBER = 1
# Set seed for reproducibility
torch.manual_seed(GROUP_NUMBER)
np.random.seed(GROUP_NUMBER)

def generate_data(n_samples=3000):
    """
    Generates 3000 sensor readings for the Kepler-186f Exclusion Zone.
    Shape: Concentric circles (Donut).
    Logic:
      - Dead Zone (1): 2km < distance < 4km
      - Safe Zone (0): distance < 2km OR distance > 4km
    """
    # Generate random coordinates between -5 and 5 km
    X = (torch.rand(n_samples, 2) * 10) - 5

    # Calculate distance from center (radius)
    radius = torch.sqrt(X[:, 0]**2 + X[:, 1]**2)

    # Assign Labels: 1 if inside the Dead Zone, 0 otherwise
    y = ((radius > 2) & (radius < 4)).float().view(-1, 1)

    # Add 5% Noise (Malfunctioning Drones)
    n_noise = int(0.05 * n_samples)
    noise_indices = torch.randperm(n_samples)[:n_noise]
    y[noise_indices] = 1 - y[noise_indices] # Flip labels

    return X, y

# Generate the dataset
X_full, y_full = generate_data(3000)

print(f"Data Generated: {X_full.shape} samples.")
print(f"Target Generated: {y_full.shape} labels.")
# Out:
# Data Generated: torch.Size([3000, 2]) samples.
# Target Generated: torch.Size([3000, 1]) labels.

# %%
def xavier_init(in_dim, out_dim):
    std = (2.0 / (in_dim + out_dim)) ** 0.5
    return torch.randn(in_dim, out_dim) * std

class Dataset:
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

    def split(self, train_ratio=0.7, seed=GROUP_NUMBER):
        torch.manual_seed(seed)
        indices = torch.randperm(len(self.X))
        train_size = int(train_ratio * len(self.X))
        train_indices = indices[:train_size]
        val_indices = indices[train_size:]
        train_dataset = Dataset(self.X[train_indices], self.y[train_indices])
        val_dataset = Dataset(self.X[val_indices], self.y[val_indices])
        return train_dataset, val_dataset

class MLP:

    def __init__(self, input_size=2, hidden_size=16, output_size=1, seed=GROUP_NUMBER):
        torch.manual_seed(seed)
        # Use Xavier initialization and make tensors require gradients
        self.W1 = xavier_init(input_size, hidden_size).requires_grad_()
        self.b1 = torch.zeros(hidden_size, requires_grad=True)

        self.W2 = xavier_init(hidden_size, hidden_size).requires_grad_()
        self.b2 = torch.zeros(hidden_size, requires_grad=True)

        self.W3 = xavier_init(hidden_size, hidden_size).requires_grad_()
        self.b3 = torch.zeros(hidden_size, requires_grad=True)

        self.W4 = xavier_init(hidden_size, output_size).requires_grad_()
        self.b4 = torch.zeros(output_size, requires_grad=True)

    def forward(self, x):
        z_1 = x @ self.W1 + self.b1
        a_1 = torch.relu(z_1)

        z_2 = a_1 @ self.W2 + self.b2
        a_2 = torch.relu(z_2)

        z_3 = a_2 @ self.W3 + self.b3
        a_3 = torch.relu(z_3)

        z_4 = a_3 @ self.W4 + self.b4
        a_4 = torch.sigmoid(z_4)

        return a_4

    def params(self):
        return [self.W1, self.b1, self.W2, self.b2, self.W3, self.b3, self.W4, self.b4]

    def reset_gradients(self):
        for param in self.params():
            param.grad = None

    def predict(self, x):
        with torch.no_grad():
            outputs = self.forward(x)
            predictions = (outputs >= 0.5).float()
        return predictions


class Trainer:

    def __init__(self, model=None, lr=0.01, epochs=100, bs=128, device='cpu', l2=0.0):
        if model is None:
            self.model = MLP()
        else:
            self.model = model
        self.lr = lr
        self.epochs = epochs
        self.bs = bs
        self.device = device
        self.l2 = l2
        self.history = { 'train_loss': [], 'val_loss': [], 'train_accuracy': [], 'val_accuracy': [] }

    def bce_loss(self, y_hat, y):
        epsilon = 1e-7  # To avoid log(0)
        outputs = torch.clamp(y_hat, epsilon, 1 - epsilon)
        loss = - (y * torch.log(outputs) + (1 - y) * torch.log(1 - outputs))
        mean_loss = loss.mean()
        return mean_loss

    def accuracy(self, y_hat, y):
        predictions = (y_hat >= 0.5).float()
        correct = (predictions == y).float().sum()
        accuracy = correct / y.shape[0]
        return float(accuracy)

    def update_params(self):
        with torch.no_grad():
            for param in self.model.params():
                if param.grad is None:
                    continue
                grad = param.grad
                # Only apply L2 to weights, not biases
                if self.l2 and param.ndim > 1:
                    grad = grad + self.l2 * param.data
                # in-place update of the underlying data
                param.data.add_(-self.lr * grad)

        for param in self.model.params():
            param.grad = None

    def train_epoch(self, train_ds):
        self.model.reset_gradients()
        total_loss = 0.0
        total_acc = 0.0
        n_batches = 0

        for i in range(0, len(train_ds), self.bs):
            X_batch = train_ds.X[i:i+self.bs].to(self.device)
            y_batch = train_ds.y[i:i+self.bs].to(self.device)

            outputs = self.model.forward(X_batch)

            loss = self.bce_loss(outputs, y_batch)

            loss.backward()

            total_loss += float(loss.detach().cpu().item())
            total_acc += self.accuracy(outputs, y_batch)

            # update parameters safely
            self.update_params()

            n_batches += 1

        if n_batches == 0:
            return float('nan'), float('nan')
        avg_loss = total_loss / n_batches
        avg_acc = total_acc / n_batches

        return avg_loss, avg_acc

    def evaluate(self, val_ds):
        with torch.no_grad():
            X_val = val_ds.X.to(self.device)
            y_val = val_ds.y.to(self.device)

            outputs = self.model.forward(X_val)
            loss = self.bce_loss(outputs, y_val)
            accuracy = self.accuracy(outputs, y_val)

        return float(loss.item()), float(accuracy)

    def train(self, train_ds, val_ds):
        for epoch in range(self.epochs):
            train_loss, train_acc = self.train_epoch(train_ds)
            val_loss, val_acc = self.evaluate(val_ds)

            self.history['train_loss'].append(train_loss)
            self.history['val_loss'].append(val_loss)
            self.history['train_accuracy'].append(train_acc)
            self.history['val_accuracy'].append(val_acc)

            if (epoch+1) % 10 == 0 or epoch == 0:
                print(f"Epoch [{epoch+1}/{self.epochs}] - Train Loss: {train_loss:.6f}, Train Acc: {train_acc:.4f} - Validation Loss: {val_loss:.6f}, Validation Acc: {val_acc:.4f}")

        return self.history

class Viz:
    @staticmethod
    def plot_metrics(history):
        epochs = range(1, len(history['train_loss']) + 1)
        plt.figure(figsize=(12, 5))

        plt.subplot(1, 2, 1)
        plt.plot(epochs, history['train_loss'], label='Train Loss', color='blue')
        plt.plot(epochs, history['val_loss'], label='Validation Loss', color='red')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title('Loss over Epochs')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(epochs, history['train_accuracy'], label='Train Accuracy', color='blue')
        plt.plot(epochs, history['val_accuracy'], label='Validation Accuracy', color='red')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title('Accuracy over Epochs')
        plt.legend()

        plt.tight_layout()
        plt.show()

    def plot_boundary(self, model: MLP, X_val: torch.Tensor, y_val: torch.Tensor, res=300):
        x_min, x_max = X_val[:,0].min().item() - 0.5, X_val[:,0].max().item() + 0.5
        y_min, y_max = X_val[:,1].min().item() - 0.5, X_val[:,1].max().item() + 0.5
        xs = torch.linspace(x_min, x_max, res)
        ys = torch.linspace(y_min, y_max, res)
        xx, yy = torch.meshgrid(xs, ys, indexing='xy')
        grid = torch.stack([xx.reshape(-1), yy.reshape(-1)], dim=1)
        with torch.no_grad():
            probs = model.forward(grid).reshape(res, res).numpy()
        plt.figure(figsize=(6,6))
        cs = plt.contour(xx.numpy(), yy.numpy(), probs, levels=[0.5], linewidths=2, colors='k')
        plt.contourf(xx.numpy(), yy.numpy(), probs, levels=50, alpha=0.6)
        y_arr = y_val.flatten().numpy()
        X_arr = X_val.numpy()
        plt.scatter(X_arr[:,0], X_arr[:,1], c=y_arr, cmap='coolwarm', edgecolors='k', s=20)
        plt.xlabel('x')
        plt.ylabel('y')
        plt.title('Geospatial Threat Map (Decision Boundary at prob=0.5)')
        plt.xlim(x_min, x_max)
        plt.ylim(y_min, y_max)
        plt.show()

# %%
if __name__ == "__main__":
    model = MLP(input_size=2, hidden_size=16, output_size=1, seed=GROUP_NUMBER)
    dataset = Dataset(X_full, y_full)
    train_ds, val_ds = dataset.split(train_ratio=0.7, seed=GROUP_NUMBER)

    trainer = Trainer(model=model, lr=0.01, epochs=400, bs=128, device='cpu', l2=0.0001)
    history = trainer.train(train_ds, val_ds)

    viz = Viz()
    viz.plot_metrics(history)
    viz.plot_boundary(model, val_ds.X, val_ds.y)

    print("Final Results:")
    print(f"Train Loss: {history['train_loss'][-1]:.6f}, Train Accuracy: {history['train_accuracy'][-1]:.4f}")
    print(f"Test Loss: {history['val_loss'][-1]:.6f}, Test Accuracy: {history['val_accuracy'][-1]:.4f}")
# Out:
# Epoch [1/400] - Train Loss: 0.707660, Train Acc: 0.4993 - Validation Loss: 0.699203, Validation Acc: 0.4833
# Epoch [10/400] - Train Loss: 0.657673, Train Acc: 0.5836 - Validation Loss: 0.648788, Validation Acc: 0.6122
# Epoch [20/400] - Train Loss: 0.649099, Train Acc: 0.5836 - Validation Loss: 0.639982, Validation Acc: 0.6122
# Epoch [30/400] - Train Loss: 0.643302, Train Acc: 0.5712 - Validation Loss: 0.634463, Validation Acc: 0.5911
# Epoch [40/400] - Train Loss: 0.637586, Train Acc: 0.5478 - Validation Loss: 0.629191, Validation Acc: 0.5667
# Epoch [50/400] - Train Loss: 0.631719, Train Acc: 0.5318 - Validation Loss: 0.623881, Validation Acc: 0.5411
# Epoch [60/400] - Train Loss: 0.625398, Train Acc: 0.5373 - Validation Loss: 0.617900, Validation Acc: 0.5556
# Epoch [70/400] - Train Loss: 0.613131, Train Acc: 0.5683 - Validation Loss: 0.606215, Validation Acc: 0.5833
# Epoch [80/400] - Train Loss: 0.601833, Train Acc: 0.6027 - Validation Loss: 0.595867, Validation Acc: 0.6356
# Epoch [90/400] - Train Loss: 0.590317, Train Acc: 0.6337 - Validation Loss: 0.584743, Validation Acc: 0.6556
# Epoch [100/400] - Train Loss: 0.578712, Train Acc: 0.6557 - Validation Loss: 0.573619, Validation Acc: 0.6700
# Epoch [110/400] - Train Loss: 0.567085, Train Acc: 0.6851 - Validation Loss: 0.562694, Validation Acc: 0.6944
# Epoch [120/400] - Train Loss: 0.554926, Train Acc: 0.7046 - Validation Loss: 0.551189, Validation Acc: 0.7222
# Epoch [130/400] - Train Loss: 0.543095, Train Acc: 0.7202 - Validation Loss: 0.539715, Validation Acc: 0.7344
# Epoch [140/400] - Train Loss: 0.531353, Train Acc: 0.7418 - Validation Loss: 0.528140, Validation Acc: 0.7500
# Epoch [150/400] - Train Loss: 0.519924, Train Acc: 0.7581 - Validation Loss: 0.516952, Validation Acc: 0.7600
# Epoch [160/400] - Train Loss: 0.508144, Train Acc: 0.7721 - Validation Loss: 0.505704, Validation Acc: 0.7733
# Epoch [170/400] - Train Loss: 0.497594, Train Acc: 0.7802 - Validation Loss: 0.495665, Validation Acc: 0.7822
# Epoch [180/400] - Train Loss: 0.487837, Train Acc: 0.7886 - Validation Loss: 0.486371, Validation Acc: 0.7889
# Epoch [190/400] - Train Loss: 0.479025, Train Acc: 0.7976 - Validation Loss: 0.477779, Validation Acc: 0.8000
# Epoch [200/400] - Train Loss: 0.471083, Train Acc: 0.8042 - Validation Loss: 0.469891, Validation Acc: 0.8067
# Epoch [210/400] - Train Loss: 0.463372, Train Acc: 0.8081 - Validation Loss: 0.462224, Validation Acc: 0.8144
# Epoch [220/400] - Train Loss: 0.455609, Train Acc: 0.8118 - Validation Loss: 0.454817, Validation Acc: 0.8167
# Epoch [230/400] - Train Loss: 0.447877, Train Acc: 0.8191 - Validation Loss: 0.447400, Validation Acc: 0.8156
# Epoch [240/400] - Train Loss: 0.439659, Train Acc: 0.8196 - Validation Loss: 0.439746, Validation Acc: 0.8156
# Epoch [250/400] - Train Loss: 0.428490, Train Acc: 0.8171 - Validation Loss: 0.429080, Validation Acc: 0.8144
# Epoch [260/400] - Train Loss: 0.419317, Train Acc: 0.8166 - Validation Loss: 0.419772, Validation Acc: 0.8133
# Epoch [270/400] - Train Loss: 0.411037, Train Acc: 0.8166 - Validation Loss: 0.410998, Validation Acc: 0.8144
# Epoch [280/400] - Train Loss: 0.402720, Train Acc: 0.8176 - Validation Loss: 0.402052, Validation Acc: 0.8089
# Epoch [290/400] - Train Loss: 0.393912, Train Acc: 0.8228 - Validation Loss: 0.392771, Validation Acc: 0.8178
# Epoch [300/400] - Train Loss: 0.385352, Train Acc: 0.8400 - Validation Loss: 0.383407, Validation Acc: 0.8378
# Epoch [310/400] - Train Loss: 0.377414, Train Acc: 0.8596 - Validation Loss: 0.373822, Validation Acc: 0.8589
# Epoch [320/400] - Train Loss: 0.369500, Train Acc: 0.8736 - Validation Loss: 0.364344, Validation Acc: 0.8733
# Epoch [330/400] - Train Loss: 0.361755, Train Acc: 0.8841 - Validation Loss: 0.355155, Validation Acc: 0.8856
# Epoch [340/400] - Train Loss: 0.354356, Train Acc: 0.8905 - Validation Loss: 0.346500, Validation Acc: 0.8944
# Epoch [350/400] - Train Loss: 0.347486, Train Acc: 0.9006 - Validation Loss: 0.338286, Validation Acc: 0.9033
# Epoch [360/400] - Train Loss: 0.341101, Train Acc: 0.9057 - Validation Loss: 0.330858, Validation Acc: 0.9089
# Epoch [370/400] - Train Loss: 0.335459, Train Acc: 0.9080 - Validation Loss: 0.324369, Validation Acc: 0.9133
# Epoch [380/400] - Train Loss: 0.330436, Train Acc: 0.9073 - Validation Loss: 0.318401, Validation Acc: 0.9156
# Epoch [390/400] - Train Loss: 0.326119, Train Acc: 0.9087 - Validation Loss: 0.313018, Validation Acc: 0.9144
# Epoch [400/400] - Train Loss: 0.322333, Train Acc: 0.9096 - Validation Loss: 0.308514, Validation Acc: 0.9156
# Final Results:
# Train Loss: 0.322333, Train Accuracy: 0.9096
# Test Loss: 0.308514, Test Accuracy: 0.9156
