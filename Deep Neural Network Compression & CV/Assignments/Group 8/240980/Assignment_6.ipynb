# %% [markdown]
# # <font size="7"> **Assignment-6**</font>
# I hope this assignment will give you clarity on how mathematical models like **Multilayer Perceptrons (MLP)** can be made from scratch using **PyTorch** & can be used to solve complex, non-linear geometric problems **without relying on black-box libraries**.
#
# ---
# # ⚫ **Mission Critical: The Exclusion Zone Protocol**
#
# **Date:** Year 2142
# **Location:** Exoplanet *Kepler-186f*   **Clearance:** IITians
#
# ---
#
# ### **⚫ The Story**
# Humanity has colonized the distant exoplanet *Kepler-186f*. While the surface is habitable, the planet's magnetic core is unstable. The **Global Defense Council (GDC)** has identified a dangerous phenomenon known as the **"Radiation Ring."**
#
# Sensors indicate that the safe zones on the planet follow a peculiar geometry:
# * ⚫ **The Core Zone:** Distance $< 2$ km from the colony center (Safe).
# * ⚫ **The Outer Wilds:** Distance $> 4$ km from the colony center (Safe).
# * ⚫ **The Dead Zone:** The region **between 2 km and 4 km** is flooded with lethal gamma radiation.
#
# Your engineering team has deployed **3,000 sensor drones** across the colony to map this danger. Each drone reports its coordinates $(x, y)$ and a binary label:
# * `1`: Radiation Detected (Dead Zone)
# * `0`: Safe Zone
#
#  **⚫ The Problem:** The sensors are cheap and prone to interference. Approximately **5%** of the drones are malfunctioning and reporting the wrong safety status (noise). The GDC mainframe is a legacy system that forbids the use of modern "Neural Libraries" (i.e., you cannot use `torch.nn` or `torch.optim`). You must build a **Multi-Layer Perceptron (MLP) from scratch** to filter out the noise and mathematically define the Exclusion Zone boundaries using **PyTorch**. ( Hint: You know this is a binary classification problem, which Loss function would you use?? )
#
# ---
#
# ### **⚫ Your Objective**
#
# 1.  **Initialize the System:** Use your **Group Number** as the random seed. This ensures your team works on a unique sensor distribution pattern.
# 2.  **Architect the Filter:** Construct a neural network with **3 hidden layers** (16 neurons each) to learn the non-linear "donut" shape of the Dead Zone.
# 3.  **Manual Calibration:** You cannot use auto-optimizers. You must manually calculate the gradients (Backpropagation) and update the system weights using **Gradient Descent**.
# 4.  **Verify Integrity:** Split your sensor data (70% training, 30% validation). Prove that your system doesn't just memorize the malfunctioning sensors (overfitting) but actually learns the geometric shape of the Dead Zone.
#
# ---
#
# ## ⚫ Engineering Constraints (Read Carefully)
#
# **1. Restricted Modules**
# *  **Forbidden:** You are strictly forbidden from importing `torch.nn` (Layers/Loss) or `torch.optim` (Optimizers).
# *  **Allowed:** `import torch`, `import matplotlib.pyplot`, `import pandas`, `import numpy`, using `sklearn`.
#
#
# **2. The Mechanics**
# * **Forward Pass:** Must be implemented using raw matrix multiplication (`torch.matmul`) and bias addition.
# * **Backward Pass:** You **MAY** use `loss.backward()` to compute gradients automatically (Autograd).
# * **Optimization:** You **MUST** implement the weight updates manually (Stochastic Gradient Descent).
#     > `w_new = w_old - learning_rate * w_old.grad`
#
# **3. Loss Function**
# Since `torch.nn` is banned, you must implement **Binary Cross Entropy** manually using basic tensor math.
#
# $$Loss = -\frac{1}{N} \sum_{i=1}^{N} [y_i \cdot \log(\hat{y}_i) + (1-y_i) \cdot \log(1-\hat{y}_i)]$$
#
# * **Note:** Ensure you handle the log of zero (numerical stability) or use `torch.clamp` to avoid `NaN` errors.
#
# **4. Visual Proof:** Your final output must include a Decision Boundary Map showing the "Donut" shape.
#
#
# ---
#
# ### ⚫ **The GDC Dashboard (Required Output)**
#
#
#
# The Global Defense Council requires visual confirmation that your system is stable before we can upload it to the drone fleet. You must generate a **3-Panel Heads-Up Display (HUD)** containing the following telemetry:
#
# **1. System Error Trajectory (Loss Plot)**
# * **Mission:** Plot the **Training Loss** (Blue) vs. **Validation Loss** (Orange) over all epochs.
# * **Why:** We need to confirm that the system is actually learning and not just diverging (exploding gradients).
#
# **2. Integrity Check (Accuracy Plot)**
# * **Mission:** Plot the **Training Accuracy** vs. **Validation Accuracy**.
# * **Why:** If Training Accuracy is high (95%) but Validation Accuracy is low (80%), you have failed to generalize. This is a sign of **Overfitting**—memorizing sensor noise instead of the Radiation Ring.
#
# **3. Geospatial Threat Map (Decision Boundary)**
# * **Mission:** Visualize the **Validation Set** on a 2D map.
# * **Overlay:** Draw the neural network's **Decision Boundary** (the contours where confidence = 0.5).
# * **Why:** The Commander needs to *see* the "Donut" shape. If your boundary looks like a jagged mess, the model is rejected.
#
# ---

# %%
import torch
import numpy as np
# ===========================================================
# PART 1: Data Generation (The Exclusion Zone)
# ===========================================================

# ⚠️ INSTRUCTION: Replace 1 with your actual Group Number
GROUP_NUMBER = 8

# Set seed for reproducibility
torch.manual_seed(GROUP_NUMBER)
np.random.seed(GROUP_NUMBER)

def generate_data(n_samples=3000):
    """
    Generates 3000 sensor readings for the Kepler-186f Exclusion Zone.
    Shape: Concentric circles (Donut).
    Logic:
      - Dead Zone (1): 2km < distance < 4km
      - Safe Zone (0): distance < 2km OR distance > 4km
    """
    # Generate random coordinates between -5 and 5 km
    X = (torch.rand(n_samples, 2) * 10) - 5

    # Calculate distance from center (radius)
    radius = torch.sqrt(X[:, 0]**2 + X[:, 1]**2)

    # Assign Labels: 1 if inside the Dead Zone, 0 otherwise
    y = ((radius > 2) & (radius < 4)).float().view(-1, 1)

    # Add 5% Noise (Malfunctioning Drones)
    n_noise = int(0.05 * n_samples)
    noise_indices = torch.randperm(n_samples)[:n_noise]
    y[noise_indices] = 1 - y[noise_indices] # Flip labels

    return X, y

# Generate the dataset
X_full, y_full = generate_data(3000)

print(f"Data Generated: {X_full.shape} samples.")
print(f"Target Generated: {y_full.shape} labels.")
# Out:
# Data Generated: torch.Size([3000, 2]) samples.
# Target Generated: torch.Size([3000, 1]) labels.

# %%
# ==============================================================================
# Code from here. Best of luckk :)
# ==============================================================================

from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X_full, y_full, test_size=0.3, random_state=GROUP_NUMBER
)

def init_params(in_dim, out_dim):
    W = torch.randn(in_dim, out_dim) * 0.1
    b = torch.zeros(1, out_dim)
    W.requires_grad_(True)
    b.requires_grad_(True)
    return W, b

W1, b1 = init_params(2, 16)
W2, b2 = init_params(16, 16)
W3, b3 = init_params(16, 16)
W4, b4 = init_params(16, 1)

def relu(x):
    return torch.clamp(x, min=0)

def sigmoid(x):
    return 1 / (1 + torch.exp(-x))

def forward(X):
    z1 = relu(X @ W1 + b1)
    z2 = relu(z1 @ W2 + b2)
    z3 = relu(z2 @ W3 + b3)
    out = sigmoid(z3 @ W4 + b4)
    return out

def bce_loss(y, y_hat):
    eps = 1e-7
    y_hat = torch.clamp(y_hat, eps, 1 - eps)
    return -torch.mean(
        y * torch.log(y_hat) + (1 - y) * torch.log(1 - y_hat)
    )


def accuracy(y, y_hat):
    preds = (y_hat >= 0.5).float()
    return (preds == y).float().mean().item()

lr = 0.05
epochs = 5000

train_losses, val_losses = [], []
train_accs, val_accs = [], []

for epoch in range(epochs):
    y_hat = forward(X_train)
    loss = bce_loss(y_train, y_hat)
    acc = accuracy(y_train, y_hat)

    loss.backward()

    with torch.no_grad():
        for W, b in [(W1,b1),(W2,b2),(W3,b3),(W4,b4)]:
            W -= lr * W.grad
            b -= lr * b.grad
            W.grad.zero_()
            b.grad.zero_()

    with torch.no_grad():
        val_hat = forward(X_val)
        val_loss = bce_loss(y_val, val_hat)
        val_acc = accuracy(y_val, val_hat)

    train_losses.append(loss.item())
    val_losses.append(val_loss.item())
    train_accs.append(acc)
    val_accs.append(val_acc)

    if epoch % 50 == 0:
        print(f"Epoch {epoch:03d} | "
              f"Train Loss: {loss.item():.4f}, Val Loss: {val_loss.item():.4f} | "
              f"Train Acc: {acc:.3f}, Val Acc: {val_acc:.3f}")

import matplotlib.pyplot as plt

plt.figure(figsize=(18,5))

# loss plot
plt.subplot(1,3,1)
plt.plot(train_losses, label="Train")
plt.plot(val_losses, label="Validation")
plt.title("System Error Trajectory")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# accuracy plot
plt.subplot(1,3,2)
plt.plot(train_accs, label="Train")
plt.plot(val_accs, label="Validation")
plt.title("Integrity Check")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

# decision boundary
plt.subplot(1,3,3)

xx, yy = torch.meshgrid(
    torch.linspace(-5,5,300),
    torch.linspace(-5,5,300),
    indexing="ij"
)

grid = torch.stack([xx.flatten(), yy.flatten()], dim=1)

with torch.no_grad():
    zz = forward(grid).reshape(xx.shape)

plt.contourf(xx, yy, zz, levels=50, cmap="coolwarm", alpha=0.6)
plt.scatter(X_val[:,0], X_val[:,1], c=y_val[:,0], s=10, cmap="coolwarm")
plt.contour(xx, yy, zz, levels=[0.5], colors='black')
plt.title("Geospatial Threat Map")

plt.tight_layout()
plt.show()
# Out:
# Epoch 000 | Train Loss: 0.6939, Val Loss: 0.6933 | Train Acc: 0.400, Val Acc: 0.462
# Epoch 050 | Train Loss: 0.6748, Val Loss: 0.6795 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 100 | Train Loss: 0.6695, Val Loss: 0.6769 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 150 | Train Loss: 0.6680, Val Loss: 0.6767 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 200 | Train Loss: 0.6674, Val Loss: 0.6769 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 250 | Train Loss: 0.6672, Val Loss: 0.6771 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 300 | Train Loss: 0.6671, Val Loss: 0.6772 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 350 | Train Loss: 0.6669, Val Loss: 0.6772 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 400 | Train Loss: 0.6668, Val Loss: 0.6771 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 450 | Train Loss: 0.6666, Val Loss: 0.6770 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 500 | Train Loss: 0.6664, Val Loss: 0.6769 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 550 | Train Loss: 0.6662, Val Loss: 0.6767 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 600 | Train Loss: 0.6659, Val Loss: 0.6765 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 650 | Train Loss: 0.6656, Val Loss: 0.6762 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 700 | Train Loss: 0.6652, Val Loss: 0.6759 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 750 | Train Loss: 0.6647, Val Loss: 0.6755 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 800 | Train Loss: 0.6641, Val Loss: 0.6750 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 850 | Train Loss: 0.6633, Val Loss: 0.6744 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 900 | Train Loss: 0.6624, Val Loss: 0.6737 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 950 | Train Loss: 0.6613, Val Loss: 0.6728 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1000 | Train Loss: 0.6600, Val Loss: 0.6718 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1050 | Train Loss: 0.6584, Val Loss: 0.6705 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1100 | Train Loss: 0.6566, Val Loss: 0.6690 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1150 | Train Loss: 0.6543, Val Loss: 0.6671 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1200 | Train Loss: 0.6516, Val Loss: 0.6647 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1250 | Train Loss: 0.6482, Val Loss: 0.6614 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1300 | Train Loss: 0.6438, Val Loss: 0.6569 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1350 | Train Loss: 0.6368, Val Loss: 0.6496 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1400 | Train Loss: 0.6273, Val Loss: 0.6390 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1450 | Train Loss: 0.6141, Val Loss: 0.6246 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1500 | Train Loss: 0.5968, Val Loss: 0.6063 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1550 | Train Loss: 0.5780, Val Loss: 0.5870 | Train Acc: 0.612, Val Acc: 0.590
# Epoch 1600 | Train Loss: 0.5590, Val Loss: 0.5672 | Train Acc: 0.615, Val Acc: 0.608
# Epoch 1650 | Train Loss: 0.5409, Val Loss: 0.5480 | Train Acc: 0.666, Val Acc: 0.659
# Epoch 1700 | Train Loss: 0.5248, Val Loss: 0.5304 | Train Acc: 0.699, Val Acc: 0.700
# Epoch 1750 | Train Loss: 0.5108, Val Loss: 0.5147 | Train Acc: 0.729, Val Acc: 0.726
# Epoch 1800 | Train Loss: 0.4989, Val Loss: 0.5009 | Train Acc: 0.748, Val Acc: 0.754
# Epoch 1850 | Train Loss: 0.4889, Val Loss: 0.4888 | Train Acc: 0.762, Val Acc: 0.769
# Epoch 1900 | Train Loss: 0.4795, Val Loss: 0.4772 | Train Acc: 0.770, Val Acc: 0.780
# Epoch 1950 | Train Loss: 0.4711, Val Loss: 0.4667 | Train Acc: 0.781, Val Acc: 0.782
# Epoch 2000 | Train Loss: 0.4656, Val Loss: 0.4598 | Train Acc: 0.788, Val Acc: 0.793
# Epoch 2050 | Train Loss: 0.4611, Val Loss: 0.4543 | Train Acc: 0.797, Val Acc: 0.798
# Epoch 2100 | Train Loss: 0.4574, Val Loss: 0.4497 | Train Acc: 0.804, Val Acc: 0.803
# Epoch 2150 | Train Loss: 0.4545, Val Loss: 0.4461 | Train Acc: 0.809, Val Acc: 0.809
# Epoch 2200 | Train Loss: 0.4522, Val Loss: 0.4431 | Train Acc: 0.812, Val Acc: 0.813
# Epoch 2250 | Train Loss: 0.4504, Val Loss: 0.4407 | Train Acc: 0.815, Val Acc: 0.820
# Epoch 2300 | Train Loss: 0.4489, Val Loss: 0.4390 | Train Acc: 0.819, Val Acc: 0.819
# Epoch 2350 | Train Loss: 0.4476, Val Loss: 0.4378 | Train Acc: 0.822, Val Acc: 0.821
# Epoch 2400 | Train Loss: 0.4466, Val Loss: 0.4366 | Train Acc: 0.822, Val Acc: 0.821
# Epoch 2450 | Train Loss: 0.4458, Val Loss: 0.4356 | Train Acc: 0.824, Val Acc: 0.821
# Epoch 2500 | Train Loss: 0.4451, Val Loss: 0.4348 | Train Acc: 0.825, Val Acc: 0.823
# Epoch 2550 | Train Loss: 0.4446, Val Loss: 0.4340 | Train Acc: 0.827, Val Acc: 0.823
# Epoch 2600 | Train Loss: 0.4441, Val Loss: 0.4333 | Train Acc: 0.827, Val Acc: 0.823
# Epoch 2650 | Train Loss: 0.4436, Val Loss: 0.4326 | Train Acc: 0.827, Val Acc: 0.823
# Epoch 2700 | Train Loss: 0.4431, Val Loss: 0.4320 | Train Acc: 0.828, Val Acc: 0.823
# Epoch 2750 | Train Loss: 0.4426, Val Loss: 0.4315 | Train Acc: 0.828, Val Acc: 0.822
# Epoch 2800 | Train Loss: 0.4422, Val Loss: 0.4309 | Train Acc: 0.828, Val Acc: 0.822
# Epoch 2850 | Train Loss: 0.4417, Val Loss: 0.4304 | Train Acc: 0.827, Val Acc: 0.823
# Epoch 2900 | Train Loss: 0.4411, Val Loss: 0.4298 | Train Acc: 0.827, Val Acc: 0.823
# Epoch 2950 | Train Loss: 0.4404, Val Loss: 0.4291 | Train Acc: 0.828, Val Acc: 0.824
# Epoch 3000 | Train Loss: 0.4396, Val Loss: 0.4284 | Train Acc: 0.828, Val Acc: 0.827
# Epoch 3050 | Train Loss: 0.4388, Val Loss: 0.4274 | Train Acc: 0.828, Val Acc: 0.827
# Epoch 3100 | Train Loss: 0.4378, Val Loss: 0.4263 | Train Acc: 0.828, Val Acc: 0.827
# Epoch 3150 | Train Loss: 0.4364, Val Loss: 0.4249 | Train Acc: 0.828, Val Acc: 0.827
# Epoch 3200 | Train Loss: 0.4346, Val Loss: 0.4228 | Train Acc: 0.829, Val Acc: 0.827
# Epoch 3250 | Train Loss: 0.4322, Val Loss: 0.4203 | Train Acc: 0.830, Val Acc: 0.828
# Epoch 3300 | Train Loss: 0.4293, Val Loss: 0.4172 | Train Acc: 0.830, Val Acc: 0.828
# Epoch 3350 | Train Loss: 0.4256, Val Loss: 0.4135 | Train Acc: 0.829, Val Acc: 0.828
# Epoch 3400 | Train Loss: 0.4214, Val Loss: 0.4090 | Train Acc: 0.830, Val Acc: 0.828
# Epoch 3450 | Train Loss: 0.4164, Val Loss: 0.4039 | Train Acc: 0.831, Val Acc: 0.827
# Epoch 3500 | Train Loss: 0.4106, Val Loss: 0.3980 | Train Acc: 0.833, Val Acc: 0.827
# Epoch 3550 | Train Loss: 0.4041, Val Loss: 0.3915 | Train Acc: 0.833, Val Acc: 0.824
# Epoch 3600 | Train Loss: 0.3973, Val Loss: 0.3850 | Train Acc: 0.833, Val Acc: 0.824
# Epoch 3650 | Train Loss: 0.3905, Val Loss: 0.3785 | Train Acc: 0.833, Val Acc: 0.824
# Epoch 3700 | Train Loss: 0.3837, Val Loss: 0.3720 | Train Acc: 0.833, Val Acc: 0.827
# Epoch 3750 | Train Loss: 0.3773, Val Loss: 0.3659 | Train Acc: 0.833, Val Acc: 0.828
# Epoch 3800 | Train Loss: 0.3710, Val Loss: 0.3602 | Train Acc: 0.833, Val Acc: 0.829
# Epoch 3850 | Train Loss: 0.3651, Val Loss: 0.3550 | Train Acc: 0.834, Val Acc: 0.827
# Epoch 3900 | Train Loss: 0.3594, Val Loss: 0.3497 | Train Acc: 0.834, Val Acc: 0.827
# Epoch 3950 | Train Loss: 0.3541, Val Loss: 0.3450 | Train Acc: 0.897, Val Acc: 0.871
# Epoch 4000 | Train Loss: 0.3491, Val Loss: 0.3407 | Train Acc: 0.901, Val Acc: 0.879
# Epoch 4050 | Train Loss: 0.3445, Val Loss: 0.3367 | Train Acc: 0.906, Val Acc: 0.884
# Epoch 4100 | Train Loss: 0.3403, Val Loss: 0.3332 | Train Acc: 0.910, Val Acc: 0.891
# Epoch 4150 | Train Loss: 0.3365, Val Loss: 0.3298 | Train Acc: 0.912, Val Acc: 0.893
# Epoch 4200 | Train Loss: 0.3329, Val Loss: 0.3268 | Train Acc: 0.914, Val Acc: 0.896
# Epoch 4250 | Train Loss: 0.3296, Val Loss: 0.3240 | Train Acc: 0.918, Val Acc: 0.900
# Epoch 4300 | Train Loss: 0.3266, Val Loss: 0.3215 | Train Acc: 0.918, Val Acc: 0.902
# Epoch 4350 | Train Loss: 0.3239, Val Loss: 0.3191 | Train Acc: 0.922, Val Acc: 0.903
# Epoch 4400 | Train Loss: 0.3214, Val Loss: 0.3170 | Train Acc: 0.923, Val Acc: 0.907
# Epoch 4450 | Train Loss: 0.3190, Val Loss: 0.3148 | Train Acc: 0.925, Val Acc: 0.909
# Epoch 4500 | Train Loss: 0.3168, Val Loss: 0.3129 | Train Acc: 0.928, Val Acc: 0.910
# Epoch 4550 | Train Loss: 0.3149, Val Loss: 0.3113 | Train Acc: 0.929, Val Acc: 0.913
# Epoch 4600 | Train Loss: 0.3131, Val Loss: 0.3098 | Train Acc: 0.929, Val Acc: 0.916
# Epoch 4650 | Train Loss: 0.3114, Val Loss: 0.3084 | Train Acc: 0.929, Val Acc: 0.916
# Epoch 4700 | Train Loss: 0.3098, Val Loss: 0.3072 | Train Acc: 0.930, Val Acc: 0.917
# Epoch 4750 | Train Loss: 0.3084, Val Loss: 0.3060 | Train Acc: 0.932, Val Acc: 0.918
# Epoch 4800 | Train Loss: 0.3071, Val Loss: 0.3050 | Train Acc: 0.933, Val Acc: 0.917
# Epoch 4850 | Train Loss: 0.3058, Val Loss: 0.3041 | Train Acc: 0.934, Val Acc: 0.917
# Epoch 4900 | Train Loss: 0.3047, Val Loss: 0.3032 | Train Acc: 0.934, Val Acc: 0.917
# Epoch 4950 | Train Loss: 0.3036, Val Loss: 0.3024 | Train Acc: 0.935, Val Acc: 0.917
